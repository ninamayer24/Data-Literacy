# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestRegressor

# %%
# read data
data = pd.read_csv('../data/filled_bridge_statistic_germany.csv', sep=';')
# remove rows with 'Traglastindex' == 0
data = data[data['Traglastindex'] != 0]
data = data.dropna()
type_encoded = pd.get_dummies(data['Teilbauwerksart'])
stadium_encoded = pd.get_dummies(data['Teilbauwerksstadium'])
superstructure_encoded = pd.get_dummies(data['Baustoff Überbau'])
federal_state_encoded = pd.get_dummies(data['Bundeslandname'])
region_encoded = pd.get_dummies(data['Kreis'])
steet_type_encoded = pd.get_dummies(data['Zugeordneter Sachverhalt vereinfacht'])

# %%
# get x, exclude non numeric columns
x = data.select_dtypes(include=['number'])
x = pd.concat([x, type_encoded, stadium_encoded, superstructure_encoded, federal_state_encoded, region_encoded, steet_type_encoded], axis=1)
x = x.drop(columns=['Unnamed: 0'])
x = x.drop(columns=["Zustandsnote"])

print(pd.DataFrame(x).isnull().sum().sum())
rows_with_nan = x[x.isnull().any(axis=1)]
print(rows_with_nan)


# get targets y 
y = data["Zustandsnote"]
# Out:
# 0
# Empty DataFrame
# Columns: [Baujahr Überbau, Baujahr Unterbau, Länge (m), Traglastindex, X, Y, Balkenbrücke / Mittelträger / Trapezplatte, Behelfsbrücke, Sonstiges System, Bogenartige Brücke / Gewölbebrücke, Bogenbrücke als Mischsystem, Bogenbrücke mit Bogenscheiben, Bogenbrücke mit abgehängter Fahrbahn, Bogenbrücke mit aufgeständerter Fahrbahn, Brücke, Brücke als Rahmen-Mischsystem, Brücke als Schrägstielrahmen, Brücke als geschlossener Rahmen, Brücke als offener Rahmen, Brücke mit Balken- / Plattenmischsystem, Brücke mit balkenartigem oder plattenartigem Tragwerk, Brücke mit einer speziellen Rahmenkonstruktionen, Drehbrücke, Festbrückengerät D-Brücke, Gewölbe- bzw. Bogenbrücke, Gewölbe-/Bogenbrücke mit Aufbeton im Verbund, Gewölbe-/Bogenbrücke mit Aufbeton ohne Verbund, Gewölbe-/Bogenbrücke mit Lastverteilungsplatte, Gewölbe-/Bogenbrücke ohne Aufbeton, Hohlkastenbrücke, Hängebrücke, Hängegurtbrücke, Klappbrücke, Plattenbalkenbrücke, Trägerrostbrücke, Plattenbrücke, Rahmenbrücke, Rahmenbrücke als Trog-Haube-Konstruktion, Rohr als Brücke, mit Ummantelung, Rohr als Brücke, ohne Ummantelung, Schrägseilbrücke, Schrägseilbrücke, Büschelsystem, Schrägseilbrücke, Fächersystem, Schrägseilbrücke, Harfensystem, Trogbrücke, Zügelgurtbrücke, BW nicht unter Verkehr, Ausf. Instandsetzung, weitr. Umleitung eigene Baulast, BW nicht unter Verkehr, Ausführ. Erneuerung/Ersatz, örtl. Umleit. eigene Baulast, BW nicht unter Verkehr, Erneuerung/Ersatzneubau in der Ausführung, BW nicht unter Verkehr, Instandsetzung in der Ausführung, BW nicht unter Verkehr, Um- und Ausbau in der Ausführung, BW unter Verkehr, Instandsetzung in der Ausführung, keine Umleitung erforderlich, Bauwerk nicht unter Verkehr, Bauwerk nicht unter Verkehr, Bauwerkserhaltung erforderlich, Bauwerk nicht unter Verkehr, Bauwerkserhaltung nicht erforderlich, Bauwerk nicht unter Verkehr, Maßnahme der Bauwerkserhaltung in der Ausführung, Bauwerk unter Verkehr, Bauwerk unter Verkehr, Erneuerung/Ersatzneubau in Planung, Bauwerk unter Verkehr, Erneuerung/Ersatzneubau in der Ausführung, Bauwerk unter Verkehr, Instandsetzung in Planung, Bauwerk unter Verkehr, Instandsetzung in der Ausführung, Bauwerk unter Verkehr, Um- und Ausbau in Planung, Bauwerk unter Verkehr, Um- und Ausbau in der Ausführung, Bauwerk unter Verkehr, Umstufung in der Vorbereitung, Maßnahme fertig gestellt, nicht unter Verkehr, Neubau fertig gestellt, nicht unter Verkehr, Beton, Geschweißtes Hohlprofil, Geschweißtes Vollprofil, Kunststoffe, transparente Materialien, Künstlicher Stein, Naturstein, Polykarbonat, Schweißprofil, Sonstige Kunststoffe, Spannbeton, Spannbetonfertigteile mit Ortbeton, Spannbetonfertigteile mit Ortbeton im Verbund, Spannbetonfertigteile mit Ortbeton ohne Verbund, Spundwand, Stahl, Stahl - Beton, Stahlbeton, Stahlbetonfertigteile mit Ortbeton, Stahlbetonfertigteile mit Ortbeton im Verbund, Stahlbetonfertigteile mit Ortbeton ohne Verbund, Stahlleichtbeton, Stahltragwerk mit Betonfertigteilen im Verbund, Stahltragwerk mit Betonplatte im Verbund, Stahltragwerk mit Betonplatte ohne Verbund, Stahlträger mit Holzbelag, Stein, Unbewehrter Beton, Verbund, Walzprofil, Walzträger in Beton, Wellprofil, Baden-Württemberg, Bayern, Berlin, Brandenburg, Bremen, ...]
# Index: []
#
# [0 rows x 493 columns]

# %%
# split data into train and test sets

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)



#scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# train linear regression model

model = LinearRegression()
model.fit(X_train_scaled, y_train)


y_pred = model.predict(X_test_scaled)
score = model.score(X_test_scaled, y_test)
error = np.mean((y_pred - y_test) ** 2)
print("Mean Squared Error:", error)
print("R^2 score:", score)

# plot predicted vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.xlabel("Actual Zustandsnote")
plt.ylabel("Predicted Zustandsnote")
plt.title("Predicted vs Actual Zustandsnote")
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.show()
# Out:
# Mean Squared Error: 0.13998877053823944
# R^2 score: 0.3262095560628515

# %%
# plot residuals

residuals = y_test - y_pred


plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='r', linestyle='--')  # Reference line for zero residual
plt.xlabel("Predicted Zustandsnote")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("Residual Plot")
plt.show()

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)

importances = rf.feature_importances_
feature_names = X_train.columns
sorted_indices = importances.argsort()[::-1]
print("Random Forest R^2:", rf.score(X_test, y_test))
    
# Plot feature importances
indices = np.argsort(importances)[-10:] # 10 most important features

plt.figure(figsize=(8, 5))
plt.barh([feature_names[i] for i in indices], importances[indices], color='skyblue')
plt.xlabel('Importance')
plt.title('Random Forest Feature Importances')
plt.tight_layout()
plt.show()
# Out:
# Länge (m): 0.214
# Baujahr Überbau: 0.160
# X: 0.124
# Y: 0.118
# Baujahr Unterbau: 0.077
# Traglastindex: 0.019
# Plattenbrücke: 0.008
# B: 0.007
# A: 0.007
# Sachsen-Anhalt: 0.006
# Plattenbalkenbrücke, Trägerrostbrücke: 0.005
# Brücke als offener Rahmen: 0.005
# Stahlbeton: 0.005
# Brücke als geschlossener Rahmen: 0.005
# Rohr als Brücke, ohne Ummantelung: 0.004
# Spannbeton: 0.004
# Bauwerk unter Verkehr: 0.003
# Nordrhein-Westfalen: 0.003
# Rheinland-Pfalz: 0.003
# Bayern: 0.003
# Hessen: 0.003
# Bauwerk unter Verkehr, Erneuerung/Ersatzneubau in Planung: 0.003
# Thueringen: 0.003
# Niedersachsen: 0.002
# Gewölbe-/Bogenbrücke ohne Aufbeton: 0.002
# Wellprofil: 0.002
# Gewölbe- bzw. Bogenbrücke: 0.002
# Landshut: 0.002
# Stahl: 0.002
# Balkenbrücke / Mittelträger / Trapezplatte: 0.002
# Karlsruhe: 0.002
# Spannbetonfertigteile mit Ortbeton im Verbund: 0.002
# Steinfurt: 0.002
# Hohlkastenbrücke: 0.002
# Kreisfreie Stadt Frankfurt Main: 0.002
# Biberach: 0.002
# Höxter: 0.002
# Ravensburg: 0.002
# Baden-Württemberg: 0.001
# Borken: 0.001
# Warendorf: 0.001
# Gütersloh: 0.001
# Landkreis Mühldorf A.Inn: 0.001
# Leipzig: 0.001
# Stahltragwerk mit Betonplatte im Verbund: 0.001
# Alb-Donau-Kreis: 0.001
# Brandenburg: 0.001
# Kassel: 0.001
# Stahlbetonfertigteile mit Ortbeton im Verbund: 0.001
# Nürnberger Land: 0.001
# Göttingen: 0.001
# Zollernalbkreis: 0.001
# Brücke mit Balken- / Plattenmischsystem: 0.001
# Brücke mit balkenartigem oder plattenartigem Tragwerk: 0.001
# Reutlingen: 0.001
# Landkreis Marburg - Biedenkopf: 0.001
# Hersfeld-Rotenburg: 0.001
# Mecklenburg-Vorpommern: 0.001
# Sachsen: 0.001
# Wetteraukreis: 0.001
# Hochsauerlandkreis: 0.001
# Erding: 0.001
# Mettmann: 0.001
# Ilm-Kreis: 0.001
# Goslar: 0.001
# Straubing-Bogen: 0.001
# Unterallgäu: 0.001
# Fulda: 0.001
# Konstanz: 0.001
# Rastatt: 0.001
# Paderborn: 0.001
# Kfr. Stadt Ludwigshafen: 0.001
# Günzburg: 0.001
# Lippe: 0.001
# Hof: 0.001
# Deggendorf: 0.001
# Dortmund: 0.001
# Bauwerk unter Verkehr, Instandsetzung in Planung: 0.001
# Waldeck-Frankenberg: 0.001
# Schwalm-Eder-Kreis: 0.001
# Darmstadt: 0.001
# Recklinghausen: 0.001
# Vogelsbergkreis: 0.001
# Rhein-Erft-Kreis: 0.001
# Würzburg: 0.001
# München: 0.001
# Ulm: 0.001
# Miesbach: 0.001
# Rohr als Brücke, mit Ummantelung: 0.001
# Zwickau: 0.001
# Unna: 0.001
# Bielefeld: 0.001
# Rottal-Inn: 0.001
# Ortenaukreis: 0.001
# Rahmenbrücke als Trog-Haube-Konstruktion: 0.001
# Lahn - Dill - Kreis: 0.001
# Gera: 0.001
# Region Hannover: 0.001
# Rhein-Hunsrück-Kreis: 0.001
# Walzträger in Beton: 0.001
# Brücke als Schrägstielrahmen: 0.001
# Sigmaringen: 0.001
# Bad Dürkheim: 0.001
# Bayreuth: 0.001
# Offenbach: 0.001
# Rhein-Neckar-Kreis: 0.001
# Essen: 0.001
# Unbewehrter Beton: 0.001
# Main - Kinzig - Kreis: 0.001
# Landkreis Bergstrasse: 0.001
# Soest: 0.001
# Rottweil: 0.001
# Emsland: 0.001
# Landkreis Neustadt A.D. Aisch - Bad Windsheim: 0.001
# Schweinfurt: 0.001
# Wesel: 0.001
# Mayen-Koblenz: 0.001
# Kronach: 0.001
# Donau-Ries: 0.001
# Bauwerk unter Verkehr, Instandsetzung in der Ausführung: 0.001
# Böblingen: 0.001
# Regensburg: 0.001
# Stuttgart: 0.001
# Vorpommern-Greifswald: 0.001
# Mainz-Bingen: 0.001
# Landkreis Neumarkt I.D.Opf.: 0.001
# Salzlandkreis: 0.001
# Neckar-Odenwald-Kreis: 0.001
# Ostallgäu: 0.001
# Esslingen: 0.001
# Gießen: 0.001
# Spannbetonfertigteile mit Ortbeton: 0.001
# Ahrweiler: 0.001
# Bernkastel-Wittlich: 0.001
# Märkischer Kreis: 0.001
# Tübingen: 0.001
# Starnberg: 0.001
# Coesfeld: 0.001
# Rhein-Kreis Neuss: 0.001
# Hagen: 0.001
# Freudenstadt: 0.001
# Bad Kissingen: 0.001
# Oberallgäu: 0.001
# Weißenburg-Gunzenhausen: 0.001
# Werra-Meißner-Kreis: 0.001
# Westerwaldkreis: 0.001
# Heilbronn: 0.001
# Sächsische Schweiz-Osterzgebirge: 0.001
# Saarland: 0.001
# Naturstein: 0.001
# Bamberg: 0.001
# Ostalb: 0.001
# Teltow-Fläming: 0.001
# Potsdam-Mittelmark: 0.001
# Haßberge: 0.001
# Herford: 0.001
# Ansbach: 0.001
# Mülheim an der Ruhr: 0.001
# Coburg: 0.001
# Weilheim-Schongau: 0.001
# Helmstedt: 0.001
# Görlitz: 0.001
# Osnabrück: 0.001
# Künstlicher Stein: 0.001
# Aschaffenburg: 0.001
# Saale-Holzland-Kreis: 0.001
# Alzey-Worms: 0.001
# Baden-Baden: 0.001
# Bodenseekreis: 0.001
# Leer: 0.001
# Rhein-Lahn-Kreis: 0.001
# Erzgebirgskreis: 0.001
# Peine: 0.001
# Schlweswig-Holstein: 0.001
# Bad Tölz-Wolfratshausen: 0.001
# Barnim: 0.001
# Rheingau - Taunus - Kreis: 0.001
# Stormarn: 0.001
# Duisburg: 0.000
# Rhein-Sieg-Kreis: 0.000
# Kleve: 0.000
# Main-Spessart: 0.000
# Augsburg: 0.000
# Dahme-Spreewald: 0.000
# Northeim: 0.000
# Neuwied: 0.000
# Aichach-Friedberg: 0.000
# Traunstein: 0.000
# Oberhausen: 0.000
# Donnersbergkreis: 0.000
# Bautzen: 0.000
# Siegen-Wittgenstein: 0.000
# Wuppertal: 0.000
# Segeberg: 0.000
# Ludwigslust-Parchim: 0.000
# Rems-Murr-Kreis: 0.000
# Regionalverband Saarbruecken: 0.000
# Düren: 0.000
# Dingolfing-Landau: 0.000
# Steinburg: 0.000
# Wesermarsch: 0.000
# Gifhorn: 0.000
# Hildesheim: 0.000
# Trier-Saarburg: 0.000
# Stahlbetonfertigteile mit Ortbeton: 0.000
# Wiesbaden: 0.000
# Kaiserslautern: 0.000
# Ostholstein: 0.000
# Rosenheim: 0.000
# Regen: 0.000
# Germersheim: 0.000
# Kitzingen: 0.000
# Minden-Lübbecke: 0.000
# Saale-Orla-Kreis: 0.000
# Freising: 0.000
# Brücke als Rahmen-Mischsystem: 0.000
# Bremen: 0.000
# Köln: 0.000
# Göppingen: 0.000
# Bad Kreuznach: 0.000
# Rendsburg-Eckernförde: 0.000
# Kelheim: 0.000
# Calw: 0.000
# Stahltragwerk mit Betonfertigteilen im Verbund: 0.000
# Viersen: 0.000
# Rhön-Grabfeld: 0.000
# Heinsberg: 0.000
# Stahl - Beton: 0.000
# Schwarzwald-Baar-Kreis: 0.000
# Mittelsachsen: 0.000
# Schwandorf: 0.000
# Saarlouis: 0.000
# Hochtaunuskreis: 0.000
# Bogenbrücke mit aufgeständerter Fahrbahn: 0.000
# Garmisch-Partenkirchen: 0.000
# Cuxhaven: 0.000
# Tirschenreuth: 0.000
# Rostock: 0.000
# Berchtesgadener Land: 0.000
# Cham: 0.000
# Passau: 0.000
# Mannheim: 0.000
# Bremen: 0.000
# Schaumburg: 0.000
# Berlin: 0.000
# Kulmbach: 0.000
# Hamburg: 0.000
# Oberhavel: 0.000
# Amberg-Sulzbach: 0.000
# Gewölbe-/Bogenbrücke mit Aufbeton ohne Verbund: 0.000
# Gewölbe-/Bogenbrücke mit Lastverteilungsplatte: 0.000
# Freyung-Grafenau: 0.000
# Main - Taunus - Kreis: 0.000
# Rhein-Pfalz-Kreis: 0.000
# Fürstenfeldbruck: 0.000
# Hamburg: 0.000
# Uckermark: 0.000
# Merzig-Wadern: 0.000
# Landkreis Neustadt A.D.Waldnaab: 0.000
# Limburg-Weilburg: 0.000
# Südwestpfalz: 0.000
# Gelsenkirchen: 0.000
# Memmingen: 0.000
# Meißen: 0.000
# Berlin: 0.000
# Oberspreewald-Lausitz: 0.000
# Ennepe-Ruhr-Kreis: 0.000
# Waldshut: 0.000
# Bonn: 0.000
# Greiz: 0.000
# Mecklenburgische Seenplatte: 0.000
# Tuttlingen: 0.000
# Ostprignitz-Ruppin: 0.000
# Münster: 0.000
# Düsseldorf: 0.000
# Roth: 0.000
# Olpe: 0.000
# Südliche Weinstrasse: 0.000
# Bauwerk unter Verkehr, Erneuerung/Ersatzneubau in der Ausführung: 0.000
# Ludwigsburg: 0.000
# Oldenburg: 0.000
# Oder-Spree: 0.000
# Stein: 0.000
# Pinneberg: 0.000
# Mainz: 0.000
# Breisgau-Hochschwarzwald: 0.000
# Dachau: 0.000
# Havelland: 0.000
# Rheinisch-Bergischer Kreis: 0.000
# Schweißprofil: 0.000
# Städteregion Aachen: 0.000
# Holzminden: 0.000
# Gewölbe-/Bogenbrücke mit Aufbeton im Verbund: 0.000
# Bochum: 0.000
# Herzogtum Lauenburg: 0.000
# Nienburg (Weser): 0.000
# Enzkreis: 0.000
# Spree-Neiße: 0.000
# Heidenheim: 0.000
# Märkisch-Oderland: 0.000
# Nordsachsen: 0.000
# Börde: 0.000
# Landkreis Wunsiedel I.Fichtelgebirge: 0.000
# Frankfurt (Oder): 0.000
# Hameln-Pyrmont: 0.000
# Wolfenbüttel: 0.000
# Lörrach: 0.000
# Braunschweig: 0.000
# Neunkirchen: 0.000
# Harburg: 0.000
# Vogtlandkreis: 0.000
# Cloppenburg: 0.000
# Altenkirchen: 0.000
# Dresden: 0.000
# Wartburgkreis: 0.000
# Landkreis Altenburg: 0.000
# Rahmenbrücke: 0.000
# Kusel: 0.000
# Forchheim: 0.000
# Eichstätt: 0.000
# Cochem-Zell: 0.000
# Bogenbrücke mit abgehängter Fahrbahn: 0.000
# Altötting: 0.000
# Vechta: 0.000
# Ammerland: 0.000
# Bottrop: 0.000
# Plön: 0.000
# Trogbrücke: 0.000
# BW unter Verkehr, Instandsetzung in der Ausführung, keine Umleitung erforderlich: 0.000
# Vulkaneifel: 0.000
# Main-Tauber-Kreis: 0.000
# Kyffhaeuserkreis: 0.000
# Erlangen-Höchstadt: 0.000
# Oberbergischer Kreis: 0.000
# Schwäbisch Hall: 0.000
# Kfr. Stadt Neustadt/Weinstraße: 0.000
# Chemnitz: 0.000
# Euskirchen: 0.000
# Landkreis Soemmerda: 0.000
# Elbe-Elster: 0.000
# Saalfeld-Rudolstadt: 0.000
# Saarpfalz-Kreis: 0.000
# Worms: 0.000
# Grafschaft Bentheim: 0.000
# Vorpommern-Rügen: 0.000
# Nordwestmecklenburg: 0.000
# Nordhausen: 0.000
# Eifelkreis Bitburg-Prüm: 0.000
# Diepholz: 0.000
# Heidekreis: 0.000
# Koblenz: 0.000
# Brücke mit einer speziellen Rahmenkonstruktionen: 0.000
# Neu-Ulm: 0.000
# Frankenthal (Pfalz): 0.000
# Hildburghausen: 0.000
# Wittenberg: 0.000
# Salzgitter: 0.000
# Spannbetonfertigteile mit Ortbeton ohne Verbund: 0.000
# Odenwaldkreis: 0.000
# Stadt Weiden I.D.Opf.: 0.000
# Birkenfeld: 0.000
# Saalekreis: 0.000
# Walzprofil: 0.000
# Ebersberg: 0.000
# Dithmarschen: 0.000
# Stahlbetonfertigteile mit Ortbeton ohne Verbund: 0.000
# Neuburg-Schrobenhausen: 0.000
# Kfr. Stadt Landau (Pfalz): 0.000
# Eisenach: 0.000
# Zweibrücken: 0.000
# Schmalkalden-Meiningen: 0.000
# Mönchengladbach: 0.000
# Potsdam: 0.000
# Erlangen: 0.000
# Weimarer Land: 0.000
# Lichtenfels: 0.000
# Bauwerk unter Verkehr, Um- und Ausbau in der Ausführung: 0.000
# Prignitz: 0.000
# Aurich: 0.000
# Nürnberg: 0.000
# Celle: 0.000
# Nordfriesland: 0.000
# Anhalt-Bitterfeld: 0.000
# Burgenlandkreis: 0.000
# Harz: 0.000
# Straubing: 0.000
# Bauwerk nicht unter Verkehr: 0.000
# Delmenhorst: 0.000
# Rotenburg (Wümme): 0.000
# Jerichower Land: 0.000
# Geschweißtes Vollprofil: 0.000
# Wilhelmshaven: 0.000
# Uelzen: 0.000
# Mansfeld-Südharz: 0.000
# Bauwerk unter Verkehr, Um- und Ausbau in Planung: 0.000
# Bogenbrücke mit Bogenscheiben: 0.000
# Miltenberg: 0.000
# Gotha: 0.000
# Stendal: 0.000
# Hohenlohekreis: 0.000
# Jena: 0.000
# Lindau (Bodensee): 0.000
# Lübeck: 0.000
# Weimar: 0.000
# Emmendingen: 0.000
# Eichsfeld: 0.000
# Festbrückengerät D-Brücke: 0.000
# Landkreis Dillingen A.D.Donau: 0.000
# Verden: 0.000
# Unstrut-Hainich-Kreis: 0.000
# Flensburg: 0.000
# Hamm: 0.000
# Lüneburg: 0.000
# BW nicht unter Verkehr, Erneuerung/Ersatzneubau in der Ausführung: 0.000
# Landsberg am Lech: 0.000
# St. Wendel: 0.000
# Heidelberg: 0.000
# Leverkusen: 0.000
# Ingolstadt: 0.000
# Herne: 0.000
# Dessau-Rosslau, Stadt: 0.000
# Lüchow-Dannenberg: 0.000
# Fürth: 0.000
# Neubau fertig gestellt, nicht unter Verkehr: 0.000
# Wolfsburg: 0.000
# Beton: 0.000
# Suhl: 0.000
# Friesland: 0.000
# Klappbrücke: 0.000
# Bauwerk nicht unter Verkehr, Bauwerkserhaltung erforderlich: 0.000
# Schleswig-Flensburg: 0.000
# Krefeld: 0.000
# Pforzheim: 0.000
# Freiburg im Breisgau: 0.000
# Cottbus: 0.000
# Trier: 0.000
# Erfurt: 0.000
# Halle (Saale): 0.000
# Kiel: 0.000
# Maßnahme fertig gestellt, nicht unter Verkehr: 0.000
# Stade: 0.000
# Kempten (Allgäu): 0.000
# Amberg: 0.000
# Bogenbrücke als Mischsystem: 0.000
# Remscheid: 0.000
# Pirmasens: 0.000
# Geschweißtes Hohlprofil: 0.000
# Speyer: 0.000
# Altmarkkreis Salzwedel: 0.000
# Bauwerk nicht unter Verkehr, Maßnahme der Bauwerkserhaltung in der Ausführung: 0.000
# Stahltragwerk mit Betonplatte ohne Verbund: 0.000
# Emden: 0.000
# Brandenburg an der Havel: 0.000
# Behelfsbrücke, Sonstiges System: 0.000
# Magdeburg: 0.000
# Bauwerk nicht unter Verkehr, Bauwerkserhaltung nicht erforderlich: 0.000
# Wittmund: 0.000
# Schwerin: 0.000
# Polykarbonat: 0.000
# Schrägseilbrücke, Harfensystem: 0.000
# Zügelgurtbrücke: 0.000
# Verbund: 0.000
# Neumünster: 0.000
# Stahlleichtbeton: 0.000
# Schwabach: 0.000
# Kaufbeuren: 0.000
# Schrägseilbrücke: 0.000
# Bundesrepublik Deutschland: 0.000
# Sonneberg: 0.000
# Osterholz: 0.000
# BW nicht unter Verkehr, Instandsetzung in der Ausführung: 0.000
# Drehbrücke: 0.000
# Brücke: 0.000
# Niedersachsen: 0.000
# Solingen: 0.000
# BW nicht unter Verkehr, Um- und Ausbau in der Ausführung: 0.000
# Mecklenburg Vorpommern: 0.000
# Bogenartige Brücke / Gewölbebrücke: 0.000
# BW nicht unter Verkehr, Ausführ. Erneuerung/Ersatz, örtl. Umleit. eigene Baulast: 0.000
# Bauwerk unter Verkehr, Umstufung in der Vorbereitung: 0.000
# Schrägseilbrücke, Büschelsystem: 0.000
# Hannover (Ehem. Regbez): 0.000
# Nrw: 0.000
# BW nicht unter Verkehr, Ausf. Instandsetzung, weitr. Umleitung eigene Baulast: 0.000
# Schrägseilbrücke, Fächersystem: 0.000
# Freiburg: 0.000
# Hängebrücke: 0.000
# Stahlträger mit Holzbelag: 0.000
# Hängegurtbrücke: 0.000
# Saarland: 0.000
# Kunststoffe, transparente Materialien: 0.000
# Spundwand: 0.000
# Sonstige Kunststoffe: 0.000

# %%
bins = [1.0, 1.4, 1.9, 2.4, 2.9, 3.4, 4.0]


data['Zustandsnotenbereich'] = pd.cut(
    data['Zustandsnote'],
    bins=bins,
    right=True,       # 1.4 belongs to "very good condition", etc.
    include_lowest=True
)

x_categorial = data.select_dtypes(include=['number'])
x_categorial = pd.concat([x_categorial, type_encoded, stadium_encoded, superstructure_encoded, federal_state_encoded, steet_type_encoded], axis=1)
x_categorial = x_categorial.drop(columns=['Unnamed: 0'])
x_categorial = x_categorial.drop(columns=["Zustandsnote"])
y_categorial = data["Zustandsnotenbereich"].cat.codes  # Convert categories to integer codes




# Assume X and y (as integer codes!) are already prepared
X_train, X_test, y_train, y_test = train_test_split(x_categorial, y_categorial, test_size=0.2, random_state=42)
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


model = LogisticRegression( solver='saga', max_iter=2000,class_weight='balanced')
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)


#train regression model (not random forrest)
model_categorial = LinearRegression()
model_categorial.fit(X_train_scaled, y_train)
y_pred_categorial = model_categorial.predict(X_test_scaled)
score_categorial = model_categorial.score(X_test_scaled, y_test)
print("Categorial Mean Squared Error:", np.mean((y_pred_categorial - y_test) ** 2))
print("Categorial R^2 score:", score_categorial)

# plot predicted vs actual values for categorial
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred_categorial, alpha=0.7)
plt.xlabel("Actual Zustandsnotenbereich")
plt.ylabel("Predicted Zustandsnotenbereich")
plt.title("Predicted vs Actual Zustandsnotenbereich")
plt.plot([y_categorial.min(), y_categorial.max()], [y_categorial.min(), y_categorial.max()], 'k--', lw=2)
plt.tight_layout()
plt.show()

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# c:\Users\pauli\miniconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Categorial Mean Squared Error: 0.6410031288038185
# Categorial R^2 score: 0.2587482705350961
#               precision    recall  f1-score   support
#
#            0       0.21      0.65      0.32       649
#            1       0.25      0.27      0.26      1536
#            2       0.60      0.24      0.34      4594
#            3       0.36      0.30      0.33      2203
#            4       0.13      0.47      0.20       378
#            5       0.03      0.58      0.05        31
#
#     accuracy                           0.30      9391
#    macro avg       0.26      0.42      0.25      9391
# weighted avg       0.44      0.30      0.32      9391
#
# [[ 423  113   60   30   10   13]
#  [ 588  414  258  164   77   35]
#  [ 840  919 1089  908  570  268]
#  [ 163  194  369  658  537  282]
#  [   3   12   25   72  179   87]
#  [   0    2    0    0   11   18]]

# %%
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.65      0.32       649
#            1       0.25      0.27      0.26      1536
#            2       0.60      0.24      0.34      4594
#            3       0.36      0.30      0.33      2203
#            4       0.13      0.47      0.20       378
#            5       0.03      0.58      0.05        31
#
#     accuracy                           0.30      9391
#    macro avg       0.26      0.42      0.25      9391
# weighted avg       0.44      0.30      0.32      9391
#
# [[ 423  113   60   30   10   13]
#  [ 588  414  258  164   77   35]
#  [ 840  919 1089  908  570  268]
#  [ 163  194  369  658  537  282]
#  [   3   12   25   72  179   87]
#  [   0    2    0    0   11   18]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(X_train, y_train)
print("Random Forest Classifier R^2:", rf_model.score(X_test, y_test))
# Out:
# Random Forest Classifier R^2: 0.5605366840592056

# %%
importances = rf_model.feature_importances_
top_n = 10
top_indices = importances.argsort()[-top_n:]
for i in reversed(top_indices):
    print(f"{X_train.columns[i]}: {importances[i]:.3f}")
# Out:
# Länge (m): 0.158
# X: 0.150
# Y: 0.148
# Baujahr Überbau: 0.125
# Baujahr Unterbau: 0.125
# Traglastindex: 0.051
# B: 0.012
# A: 0.012
# Plattenbrücke: 0.012
# Spannbeton: 0.012

# %%
print(classification_report(y_test, rf_model.predict(X_test)))
print(confusion_matrix(y_test, rf_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.35      0.40       649
#            1       0.44      0.35      0.39      1536
#            2       0.61      0.74      0.67      4594
#            3       0.52      0.46      0.49      2203
#            4       0.47      0.27      0.34       378
#            5       0.24      0.13      0.17        31
#
#     accuracy                           0.56      9391
#    macro avg       0.46      0.38      0.41      9391
# weighted avg       0.55      0.56      0.55      9391
#
# [[ 227  163  242   17    0    0]
#  [ 146  535  757   98    0    0]
#  [  94  441 3388  639   32    0]
#  [  10   78 1025 1009   77    4]
#  [   0    3  106  159  101    9]
#  [   0    0    7   17    3    4]]
